# %% [markdown]
# ## Brouwer's database of srg's
# (joint work with Nathann Cohen)
#
#   Andries Brouwer maintains a [public database](https://www.win.tue.nl/~aeb/graphs/srg/srgtab.html) of existence results for strongly regular graphs on
#   $n\leq 1300$ vertices. We have implemented most of the infinite families of graphs
#   listed there in Sagemath, as well as
#   provided constructions of the "sporadic" cases, to obtain a graph for each
#   set of parameters with known examples (about 5 are still to be added, as of March 2018).

# %%
petersen=graphs.strongly_regular_graph(10,3,0); petersen
# Out:
# complement(Johnson graph with parameters 5,2): Graph on 10 vertices

# %%
petersen.is_strongly_regular?

# %%
graphs.T2starGeneralizedQuadrangleGraph?

# %%
graphs.strongly_regular_graph(276,135,78)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-39579da04273> in <module>()
# ----> 1 graphs.strongly_regular_graph(Integer(276),Integer(135),Integer(78))
#
# /home/dima/Sage/sage-dev/local/lib/python2.7/site-packages/sage/graphs/strongly_regular_db.pyx in sage.graphs.strongly_regular_db.strongly_regular_graph (build/cythonized/sage/graphs/strongly_regular_db.c:43136)()
#    2918     if params_complement in _small_srg_database:
#    2919         val = _small_srg_database[params_complement]
# -> 2920         return True if existence else check_srg(val[0](*val[1:]).complement())
#    2921
#    2922     test_functions = [is_complete_multipartite, # must be 1st, to prevent 0-divisions
#
# /home/dima/Sage/sage-dev/local/lib/python2.7/site-packages/sage/graphs/strongly_regular_db.pyx in sage.graphs.strongly_regular_db.SRG_276_140_58_84 (build/cythonized/sage/graphs/strongly_regular_db.c:34041)()
#    2272     """
#    2273     from sage.graphs.generators.smallgraphs import McLaughlinGraph
# -> 2274     g = McLaughlinGraph()
#    2275     C = [[ 0,  72,  87, 131, 136], [ 1,  35,  61, 102, 168], [ 2,  32,  97, 125, 197], [ 3,  22,  96, 103, 202],
#    2276          [ 4,  46,  74, 158, 229], [ 5,  83,  93, 242, 261], [ 6,  26,  81, 147, 176], [ 7,  42,  63, 119, 263],
#
# /home/dima/Sage/sage-dev/local/lib/python2.7/site-packages/sage/graphs/generators/smallgraphs.pyc in McLaughlinGraph()
#    3777     from sage.sets.set import Set
#    3778
# -> 3779     blocks = [Set(_) for _ in WittDesign(23).blocks()]
#    3780
#    3781     B = [b for b in blocks if 0     in b]
#
# /home/dima/Sage/sage-dev/local/lib/python2.7/site-packages/sage/combinat/designs/block_design.pyc in WittDesign(n)
#     938     """
#     939     from sage.interfaces.gap import gap
# --> 940     gap.load_package("design")
#     941     gap.eval("B:=WittDesign(%s)"%n)
#     942     v = eval(gap.eval("B.v"))
#
# /home/dima/Sage/sage-dev/local/lib/python2.7/site-packages/sage/interfaces/gap.pyc in load_package(self, pkg, verbose)
#     517         if x == 'fail':
#     518             raise RuntimeError("Error loading Gap package "+str(pkg)+". "+
# --> 519                                "You may want to install the gap_packages and/or database_gap SPKGs.")
#     520
#     521     def eval(self, x, newlines=False, strip=True, split_lines=True, **kwds):
#
# RuntimeError: Error loading Gap package design. You may want to install the gap_packages and/or database_gap SPKGs.
